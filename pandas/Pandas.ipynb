# %% [markdown]
# # Pandas
#
# [Tutorial Video](https://www.youtube.com/watch?v=vmEHCJofslg)
#
# [Tutorial Repository](https://github.com/KeithGalli/pandas)
#
# [Pandas](https://pandas.pydata.org/docs/reference/index.html#api)

# %% [markdown]
# ## Load data from file

# %%
import pandas as pd
df = pd.read_csv('./pokemon_data.csv')
print(df.head(3))
print(df.tail(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df_xl = pd.read_excel('pokemon_data.xlsx')
print(df_xl.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %% [markdown]
# ***For txt add eg., delmiter='\t'***

# %% [markdown]
# ## Reading Data in Pandas

# %% [markdown]
# ***Column Headers***

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ***Read a column***

# %%
df[['Name', 'Type 1']][0:5]
# Out:
#                     Name Type 1
# 0              Bulbasaur  Grass
# 1                Ivysaur  Grass
# 2               Venusaur  Grass
# 3  VenusaurMega Venusaur  Grass
# 4             Charmander   Fire

# %% [markdown]
# **Read a row**
#
# ***iloc***

# %%
df.iloc[1:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %% [markdown]
# ***iterrows***

# %%
count = 0
for index, row in df.iterrows():
  if count < 5:
    print(index,row['Name'])
    count += 1
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander

# %% [markdown]
# ***loc***
#
# For non-integer information

# %%
df.loc[(df['Type 1'] == "Fire") & (df['Type 2'] == 'Flying')]
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard   Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 158  146                    Moltres   Fire  Flying   90     100       90
# 270  250                      Ho-oh   Fire  Flying  106     130       90
# 730  662                Fletchinder   Fire  Flying   62      73       55
# 731  663                 Talonflame   Fire  Flying   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6        109       85    100           1      False
# 8        159      115    100           1      False
# 158      125       85     90           1       True
# 270      110      154     90           2       True
# 730       56       52     84           6      False
# 731       74       69    126           6      False

# %% [markdown]
# ## Making changes to the data

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# **Add a column with totals for stats**

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df = df.drop(columns=['Total'])
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ***With iloc***

# %% [markdown]
# While this is easer it could break if the column order has been changed

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# **Rearrange Columns**
#
# Note that a single-column slice returns a string so it must be made an array

# %%
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:-1]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## Saving/Exporting Data

# %%
df.to_csv('modified.csv', index=False) # remove the index column
df.to_excel('modified.xlsx', index=False)
df.to_csv('modified.txt', index=False, sep="\t")

# %% [markdown]
# ## Filtering Data

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')].head(5)
# Out:
#      #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1              Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                Ivysaur  Grass  Poison    405  60      62       63
# 2    3               Venusaur  Grass  Poison    525  80      82       83
# 3    3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 48  43                 Oddish  Grass  Poison    320  45      50       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 48       75       65     30           1      False

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')].head(5)
# Out:
#      #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1              Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                Ivysaur  Grass  Poison    405  60      62       63
# 2    3               Venusaur  Grass  Poison    525  80      82       83
# 3    3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 16  13                 Weedle    Bug  Poison    195  40      35       30
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 16       20       20     50           1      False

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
print(new_df.head(6))
new_df = new_df.reset_index(drop=True) # drop prevents creation of a new column with the old index number
print(new_df.head(6))
# Out:
#      #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1              Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                Ivysaur  Grass  Poison    405  60      62       63
# 2    3               Venusaur  Grass  Poison    525  80      82       83
# 3    3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 16  13                 Weedle    Bug  Poison    195  40      35       30
# 17  14                 Kakuna    Bug  Poison    205  45      25       50
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 16       20       20     50           1      False
# 17       25       25     35           1      False
#     #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1              Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                Ivysaur  Grass  Poison    405  60      62       63
# 2   3               Venusaur  Grass  Poison    525  80      82       83
# 3   3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  13                 Weedle    Bug  Poison    195  40      35       30
# 5  14                 Kakuna    Bug  Poison    205  45      25       50
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       20       20     50           1      False
# 5       25       25     35           1      False

# %%
df.loc[df['Name'].str.contains('Mega')].head(5)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3       122      120     80           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 12      135      115     78           1      False
# 19       15       80    145           1      False

# %%
df.loc[~df['Name'].str.contains('Mega')].head(5)
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 4     65           1      False
# 5     80           1      False

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)].head(6)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %% [markdown]
# ***Case insentive***

# %%
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)].head(6)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %%
df.loc[df['Name'].str.contains('^Pi', regex=True)].head(6)
# Out:
#        #                 Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 20    16               Pidgey    Normal  Flying    251  40      45       40
# 21    17            Pidgeotto    Normal  Flying    349  63      60       55
# 22    18              Pidgeot    Normal  Flying    479  83      80       75
# 23    18  PidgeotMega Pidgeot    Normal  Flying    579  83      80       80
# 30    25              Pikachu  Electric     NaN    320  35      55       40
# 136  127               Pinsir       Bug     NaN    500  65     125      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20        35       35     56           1      False
# 21        50       50     71           1      False
# 22        70       70    101           1      False
# 23       135       80    121           1      False
# 30        50       50     90           1      False
# 136       55       70     85           1      False

# %% [markdown]
# ## Conditional Changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
df.head(6)
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur   Grass  Poison    318  45      49       49
# 1  2                Ivysaur   Grass  Poison    405  60      62       63
# 2  3               Venusaur   Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4  4             Charmander  Flamer     NaN    309  39      52       43
# 5  5             Charmeleon  Flamer     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %%
df.loc[df['Type 1'] == 'Grass', 'Legendary'] = True
df.head(6)
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur   Grass  Poison    318  45      49       49
# 1  2                Ivysaur   Grass  Poison    405  60      62       63
# 2  3               Venusaur   Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4  4             Charmander  Flamer     NaN    309  39      52       43
# 5  5             Charmeleon  Flamer     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1       True
# 1       80       80     60           1       True
# 2      100      100     80           1       True
# 3      122      120     80           1       True
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %%
df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = [2, True]
df.head(6)
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur   Grass  Poison    318  45      49       49
# 1  2                Ivysaur   Grass  Poison    405  60      62       63
# 2  3               Venusaur   Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4  4             Charmander  Flamer     NaN    309  39      52       43
# 5  5             Charmeleon  Flamer     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1       True
# 1       80       80     60           1       True
# 2      100      100     80           2       True
# 3      122      120     80           2       True
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %% [markdown]
# ## Aggregation

# %%
df = pd.read_csv('modified.csv')
df.groupby(['Type 1']).mean(numeric_only=True).sort_values('Defense', ascending=False).head(6)
# Default numeric_only = True is deprecated
# Out:
#                  #       Total         HP      Attack     Defense    Sp. Atk  \
# Type 1
# Steel   442.851852  487.703704  65.222222   92.703704  126.370370  67.518519
# Rock    392.727273  453.750000  65.363636   92.863636  100.795455  63.340909
# Dragon  474.375000  550.531250  83.312500  112.125000   86.375000  96.843750
# Ground  356.281250  437.500000  73.781250   95.750000   84.843750  56.468750
# Ghost   486.500000  439.562500  64.437500   73.781250   81.187500  79.343750
# Water   303.089286  430.455357  72.062500   74.151786   72.946429  74.812500
#
#           Sp. Def      Speed  Generation  Legendary
# Type 1
# Steel   80.629630  55.259259    3.851852   0.148148
# Rock    75.477273  55.909091    3.454545   0.090909
# Dragon  88.843750  83.031250    3.875000   0.375000
# Ground  62.750000  63.906250    3.156250   0.125000
# Ghost   76.468750  64.343750    4.187500   0.062500
# Water   70.517857  65.964286    2.857143   0.035714

# %%
df.groupby(['Type 1']).sum(numeric_only=True).head(6) # Default True is deprecated
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       23080  26146  3925    4897     4880     3717     4471   4256
# Dark      14302  13818  2071    2740     2177     2314     2155   2361
# Dragon    15180  17617  2666    3588     2764     3099     2843   2657
# Electric  15994  19510  2631    3040     2917     3961     3243   3718
# Fairy      7642   7024  1260    1046     1117     1335     1440    826
# Fighting   9824  11244  1886    2613     1780     1434     1747   1784
#
#           Generation  Legendary
# Type 1
# Bug              222          0
# Dark             125          2
# Dragon           124         12
# Electric         144          4
# Fairy             70          1
# Fighting          91          0

# %%
df.groupby(['Type 1']).count().head(6)
# Out:
#            #  Name  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug       69    69      52     69  69      69       69       69       69
# Dark      31    31      21     31  31      31       31       31       31
# Dragon    32    32      21     32  32      32       32       32       32
# Electric  44    44      17     44  44      44       44       44       44
# Fairy     17    17       2     17  17      17       17       17       17
# Fighting  27    27       7     27  27      27       27       27       27
#
#           Speed  Generation  Legendary
# Type 1
# Bug          69          69         69
# Dark         31          31         31
# Dragon       32          32         32
# Electric     44          44         44
# Fairy        17          17         17
# Fighting     27          27         27

# %%
df['count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['count'].head(16)
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#         Grass        6
#         Ground       2
#         Poison      12
#         Rock         3
#         Steel        7
#         Water        1
# Dark    Dragon       3
#         Fighting     2
#         Fire         3
#         Flying       5
#         Ghost        2
# Name: count, dtype: int64

# %% [markdown]
# ## Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
  results = df.groupby(['Type 1']).count()
  new_df = pd.concat([new_df, results])
  
new_df
# Out:
#          # Name Type 1 Type 2 Total HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1    1    NaN      0     1  1      1       1       1       1     1
# Grass    4    4    NaN      4     4  4      4       4       4       4     4
# Fire     4    4    NaN      3     4  4      4       4       4       4     4
# Water    1    1    NaN      0     1  1      1       1       1       1     1
# Bug      2    2    NaN      0     2  2      2       2       2       2     2
# ...     ..  ...    ...    ...   ... ..    ...     ...     ...     ...   ...
# Fairy    1    1    NaN      0     1  1      1       1       1       1     1
# Flying   2    2    NaN      2     2  2      2       2       2       2     2
# Fire     1    1    NaN      1     1  1      1       1       1       1     1
# Psychic  2    2    NaN      2     2  2      2       2       2       2     2
# Rock     2    2    NaN      2     2  2      2       2       2       2     2
#
#         Generation Legendary count
# Fire             1         1   NaN
# Grass            4         4   NaN
# Fire             4         4   NaN
# Water            1         1   NaN
# Bug              2         2   NaN
# ...            ...       ...   ...
# Fairy            1         1   NaN
# Flying           2         2   NaN
# Fire             1         1   NaN
# Psychic          2         2   NaN
# Rock             2         2   NaN
#
# [433 rows x 14 columns]

# %% [markdown]
# ## Extract tables from Websites
#
# [Video Source](https://www.youtube.com/watch?v=PXMJ6FS7llk)

# %% [markdown]
# simpsons = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')

# %%
len(simpsons)
# Out:
# 23

# %%
simpsons[1]
# Out:
#     No.overall  No. inseason                                Title  \
# 0            1             1  "Simpsons Roasting on an Open Fire"
# 1            2             2                    "Bart the Genius"
# 2            3             3                    "Homer's Odyssey"
# 3            4             4      "There's No Disgrace Like Home"
# 4            5             5                   "Bart the General"
# 5            6             6                       "Moaning Lisa"
# 6            7             7           "The Call of the Simpsons"
# 7            8             8                  "The Telltale Head"
# 8            9             9              "Life on the Fast Lane"
# 9           10            10                  "Homer's Night Out"
# 10          11            11                "The Crepes of Wrath"
# 11          12            12                 "Krusty Gets Busted"
# 12          13            13             "Some Enchanted Evening"
#
#                            Directed by  \
# 0                      David Silverman
# 1                      David Silverman
# 2                           Wes Archer
# 3       Gregg Vanzo & Kent Butterworth
# 4                      David Silverman
# 5                           Wes Archer
# 6                           Wes Archer
# 7                           Rich Moore
# 8                      David Silverman
# 9                           Rich Moore
# 10            Wes Archer & Milton Gray
# 11                           Brad Bird
# 12  David Silverman & Kent Butterworth
#
#                                            Written by  Original air date  \
# 0                                           Mimi Pond  December 17, 1989
# 1                                           Jon Vitti   January 14, 1990
# 2                      Jay Kogen & Wallace Wolodarsky   January 21, 1990
# 3                                Al Jean & Mike Reiss   January 28, 1990
# 4                                   John Swartzwelder   February 4, 1990
# 5                                Al Jean & Mike Reiss  February 11, 1990
# 6                                   John Swartzwelder  February 18, 1990
# 7      Al Jean, Mike Reiss, Sam Simon & Matt Groening  February 25, 1990
# 8                                   John Swartzwelder     March 18, 1990
# 9                                           Jon Vitti     March 25, 1990
# 10  George Meyer, Sam Simon, John Swartzwelder & J...     April 15, 1990
# 11                     Jay Kogen & Wallace Wolodarsky     April 29, 1990
# 12                          Matt Groening & Sam Simon       May 13, 1990
#
#    Prod.code U.S. viewers(millions)
# 0       7G08               26.7[46]
# 1       7G02               24.5[46]
# 2       7G03               27.5[47]
# 3       7G04               20.2[48]
# 4       7G05               27.1[49]
# 5       7G06               27.4[50]
# 6       7G09               27.6[51]
# 7       7G07                 28[52]
# 8       7G11               33.5[53]
# 9       7G10               30.3[54]
# 10      7G13               31.2[55]
# 11      7G12               30.4[56]
# 12      7G01               27.1[57]

# %% [markdown]
# ## Scraping: Extract CSV from Weebsites

# %% [markdown]
# **reading 1 csv file from website**

# %%
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/E0.csv')

# %% [markdown]
# **showing dataframe**

# %%
df_premier21
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal     0     2   A
# 1    E0  06/08/2022  12:30          Fulham      Liverpool     2     2   D
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa     2     0   H
# 3    E0  06/08/2022  15:00           Leeds         Wolves     2     1   H
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest     2     0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 153  E0  27/12/2022  17:30         Chelsea    Bournemouth     2     0   H
# 154  E0  27/12/2022  20:00      Man United  Nott'm Forest     3     0   H
# 155  E0  28/12/2022  20:00           Leeds       Man City     1     3   A
# 156  E0  30/12/2022  19:45        West Ham      Brentford     0     2   A
# 157  E0  30/12/2022  20:00       Liverpool      Leicester     2     1   H
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 0       0     1  ...     1.76  0.50      2.09      1.84   2.04   1.88
# 1       1     0  ...     2.73  1.75      1.90      2.03   1.91   2.02
# 2       1     0  ...     1.76  0.50      1.93      2.00   1.93   2.00
# 3       1     1  ...     1.87 -0.25      2.08      1.85   2.10   1.84
# 4       0     0  ...     1.89 -1.00      1.97      1.96   1.99   1.93
# ..    ...   ...  ...      ...   ...       ...       ...    ...    ...
# 153     2     0  ...     2.28 -1.50      2.02      1.88   2.04   1.88
# 154     2     0  ...     2.63 -1.50      1.91      1.99   1.93   2.00
# 155     0     1  ...     3.06  1.75      1.98      1.95   1.97   1.93
# 156     0     2  ...     1.97 -0.25      1.77      2.02   1.86   2.07
# 157     2     1  ...     2.88 -1.75      1.84      2.09   1.81   2.10
#
#      MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.09     1.88     2.03     1.85
# 1       2.01     2.06     1.89     1.99
# 2       1.94     2.04     1.88     2.00
# 3       2.14     1.87     2.08     1.81
# 4       2.19     1.97     2.03     1.86
# ..       ...      ...      ...      ...
# 153     2.05     2.01     2.00     1.88
# 154     1.97     2.10     1.91     1.96
# 155     2.10     1.97     1.96     1.90
# 156     1.86     2.16     1.79     2.09
# 157     1.85     2.17     1.82     2.06
#
# [158 rows x 106 columns]

# %% [markdown]
# **rename columns**

# %%
df_premier21.rename(columns={'FTHG': 'home_goals',
                             'FTAG': 'away_goals'}, inplace=True)

# %%
df_premier21
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  home_goals  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal           0
# 1    E0  06/08/2022  12:30          Fulham      Liverpool           2
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa           2
# 3    E0  06/08/2022  15:00           Leeds         Wolves           2
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest           2
# ..   ..         ...    ...             ...            ...         ...
# 153  E0  27/12/2022  17:30         Chelsea    Bournemouth           2
# 154  E0  27/12/2022  20:00      Man United  Nott'm Forest           3
# 155  E0  28/12/2022  20:00           Leeds       Man City           1
# 156  E0  30/12/2022  19:45        West Ham      Brentford           0
# 157  E0  30/12/2022  20:00       Liverpool      Leicester           2
#
#      away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# 0             2   A     0     1  ...     1.76  0.50      2.09      1.84
# 1             2   D     1     0  ...     2.73  1.75      1.90      2.03
# 2             0   H     1     0  ...     1.76  0.50      1.93      2.00
# 3             1   H     1     1  ...     1.87 -0.25      2.08      1.85
# 4             0   H     0     0  ...     1.89 -1.00      1.97      1.96
# ..          ...  ..   ...   ...  ...      ...   ...       ...       ...
# 153           0   H     2     0  ...     2.28 -1.50      2.02      1.88
# 154           0   H     2     0  ...     2.63 -1.50      1.91      1.99
# 155           3   A     0     1  ...     3.06  1.75      1.98      1.95
# 156           2   A     0     2  ...     1.97 -0.25      1.77      2.02
# 157           1   H     2     1  ...     2.88 -1.75      1.84      2.09
#
#      PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.04   1.88     2.09     1.88     2.03     1.85
# 1     1.91   2.02     2.01     2.06     1.89     1.99
# 2     1.93   2.00     1.94     2.04     1.88     2.00
# 3     2.10   1.84     2.14     1.87     2.08     1.81
# 4     1.99   1.93     2.19     1.97     2.03     1.86
# ..     ...    ...      ...      ...      ...      ...
# 153   2.04   1.88     2.05     2.01     2.00     1.88
# 154   1.93   2.00     1.97     2.10     1.91     1.96
# 155   1.97   1.93     2.10     1.97     1.96     1.90
# 156   1.86   2.07     1.86     2.16     1.79     2.09
# 157   1.81   2.10     1.85     2.17     1.82     2.06
#
# [158 rows x 106 columns]

# %% [markdown]
# ## Extract Tables from PDFs

# %%
# !pip install tk
# !pip install ghostscript
# !pip install 'PyPDF2<3.0'
# !pip install opencv-python
# !pip install "camelot-py[base]"
# Out:
# Requirement already satisfied: tk in /home/biscotty/anaconda3/lib/python3.9/site-packages (0.1.0)
# Requirement already satisfied: ghostscript in /home/biscotty/anaconda3/lib/python3.9/site-packages (0.7)
# Requirement already satisfied: setuptools>=38.6.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from ghostscript) (65.5.0)
# Requirement already satisfied: PyPDF2<3.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (2.12.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from PyPDF2<3.0) (4.4.0)
# Requirement already satisfied: opencv-python in /home/biscotty/anaconda3/lib/python3.9/site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.17.3 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from opencv-python) (1.21.5)
# Requirement already satisfied: camelot-py[base] in /home/biscotty/anaconda3/lib/python3.9/site-packages (0.10.1)
# Requirement already satisfied: tabulate>=0.8.9 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (0.8.10)
# Requirement already satisfied: chardet>=3.0.4 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (5.0.0)
# Requirement already satisfied: pandas>=0.23.4 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (1.4.4)
# Requirement already satisfied: pdfminer.six>=20200726 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (20221105)
# Requirement already satisfied: PyPDF2>=1.26.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (2.12.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (1.21.5)
# Requirement already satisfied: openpyxl>=2.5.8 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (3.0.10)
# Requirement already satisfied: click>=6.7 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (8.1.3)
# Requirement already satisfied: opencv-python>=3.4.2.17 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (4.7.0.68)
# Requirement already satisfied: ghostscript>=0.7 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (0.7)
# Requirement already satisfied: pdftopng>=0.2.3 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from camelot-py[base]) (0.2.3)
# Requirement already satisfied: setuptools>=38.6.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from ghostscript>=0.7->camelot-py[base]) (65.5.0)
# Requirement already satisfied: et_xmlfile in /home/biscotty/anaconda3/lib/python3.9/site-packages (from openpyxl>=2.5.8->camelot-py[base]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from pandas>=0.23.4->camelot-py[base]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from pandas>=0.23.4->camelot-py[base]) (2022.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from pdfminer.six>=20200726->camelot-py[base]) (2.1.1)
# Requirement already satisfied: cryptography>=36.0.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from pdfminer.six>=20200726->camelot-py[base]) (38.0.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from PyPDF2>=1.26.0->camelot-py[base]) (4.4.0)
# Requirement already satisfied: cffi>=1.12 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[base]) (1.15.1)
# Requirement already satisfied: six>=1.5 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.23.4->camelot-py[base]) (1.16.0)
# Requirement already satisfied: pycparser in /home/biscotty/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[base]) (2.21)

# %%
import camelot

# %%
tables = camelot.read_pdf('foo.pdf', pages='1')

# %%
print(tables)
# Out:
# <TableList n=1>

# %%
print('hello')

# %%
tables.export('foo.csv', f='csv', compress=True)
tables[0].to_csv('foo.csv')

# %% [markdown]
# ## Web Automation and Scraping: HTML - Tags
#
# [source](https://subslikescript.com/movie/Titanic-120338)
#
# Elements, Attributes and Text are nodes
#
# article element is root node
#
# All nodes have one parent

# %% [markdown]
# **XPath**
#
# Similar to css in syntax
#
# //tagName[@AttributeName="Value"]
#
# Functions:
# - contains()     //tagName[contains(@AttributeName, "Value")]
# - starts-with()
# - and/or         //tagName[(expression 1) and (expression2)]

# %%
import html

# %%
input = html.unescape('<article class ="main-article"><h1> Titanic(1997) </h1><p class ="plot" > 84 years later... </p><p class ="plot2" > In the end ... </p><div class ="full-script">"13 meters. You should see it. ""Okay, take her up and over the bow rail. "</div></article>')

# %% [markdown]
# **XPath Special Characters**
#
# - / : Select children on left side
# - // : Specifies that matching node can be at any level
# - . : Refers to current node
# - .. : Refers to parent node
# - \* : Selects all children
# - @ : Select an attribute
# - () : Grouping expressions
# - [n] : Specifies a node by it's index

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.7.2-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 7.1 MB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: urllib3[socks]~=1.26 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from selenium) (1.26.13)
# Requirement already satisfied: certifi>=2021.10.8 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from selenium) (2022.9.24)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (22.1.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: sniffio in /home/biscotty/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: sortedcontainers in /home/biscotty/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: idna in /home/biscotty/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.4)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /home/biscotty/anaconda3/lib/python3.9/site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.1.0 h11-0.14.0 outcome-1.2.0 selenium-4.7.2 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0

# %% [markdown]
# ## Automate the News

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

options = Options()
options.binary_location = "/home/biscotty/.selenium/chrome"
service = Service(executable_path=r'/home/biscotty/.selenium/chromedriver')
driver = webdriver.Chrome(service=service)

website = "https://thesun.co.uk/sport/football/"

driver.get(website)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /tmp/ipykernel_86342/70222976.py in <module>
#       6 options.binary_location = "/home/biscotty/.selenium/chrome"
#       7 service = Service(executable_path=r'/home/biscotty/.selenium/chromedriver')
# ----> 8 driver = webdriver.Chrome(service=service)
#       9
#      10 website = "https://thesun.co.uk/sport/football/"
#
# ~/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      79             service = Service(executable_path, port, service_args, service_log_path)
#      80
# ---> 81         super().__init__(
#      82             DesiredCapabilities.CHROME["browserName"],
#      83             "goog",
#
# ~/anaconda3/lib/python3.9/site-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#     104
#     105         try:
# --> 106             super().__init__(
#     107                 command_executor=ChromiumRemoteConnection(
#     108                     remote_server_addr=self.service.service_url,
#
# ~/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     286         self._authenticator_id = None
#     287         self.start_client()
# --> 288         self.start_session(capabilities, browser_profile)
#     289
#     290     def __repr__(self):
#
# ~/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     379         w3c_caps = _make_w3c_caps(capabilities)
#     380         parameters = {"capabilities": w3c_caps}
# --> 381         response = self.execute(Command.NEW_SESSION, parameters)
#     382         if "sessionId" not in response:
#     383             response = response["value"]
#
# ~/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
# --> 444             self.error_handler.check_response(response)
#     445             response["value"] = self._unwrap_value(response.get("value", None))
#     446             return response
#
# ~/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     247                 alert_text = value["alert"].get("text")
#     248             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249         raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: DevToolsActivePort file doesn't exist
# Stacktrace:
# #0 0x564fa1a1b2a3 <unknown>
# #1 0x564fa17d9f77 <unknown>
# #2 0x564fa1805fc4 <unknown>
# #3 0x564fa1801b0c <unknown>
# #4 0x564fa17fe7d0 <unknown>
# #5 0x564fa183f0b7 <unknown>
# #6 0x564fa183ea5f <unknown>
# #7 0x564fa1836903 <unknown>
# #8 0x564fa1809ece <unknown>
# #9 0x564fa180afde <unknown>
# #10 0x564fa1a6b63e <unknown>
# #11 0x564fa1a6eb79 <unknown>
# #12 0x564fa1a5189e <unknown>
# #13 0x564fa1a6fa83 <unknown>
# #14 0x564fa1a44505 <unknown>
# #15 0x564fa1a90ca8 <unknown>
# #16 0x564fa1a90e36 <unknown>
# #17 0x564fa1aac333 <unknown>
# #18 0x7fb580a9eb43 <unknown>

# %%
driver.find_element(by="xpath", value="//div[@class='teaser__copy-container']")

#  //div[@class='teaser__copy-container']
